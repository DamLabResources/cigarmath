# %%
import sys
sys.path.append('../')

# %%
import cigarmath as cm
# %matplotlib inline

# %% [markdown]
# # Plotting Mapped regions

# %%
stream = cm.io.segment_stream_pysam('../tests/test_data/test.sam', 
                                    mode='r', progbar=True)
bmp = cm.plotting.BinaryMapPlot.from_samstream(stream, sort='mapped_bases',
                                               max_genome_size=9717,
                                               deletion_size=50)
# Out:
# 248it [00:00, 11606.90it/s]

# %%
bmp.plot_map()
# Out:
# <AxesSubplot: xlabel='Genomic Position', ylabel='Reads'>

# %%
bmp.plot_hist()
# Out:
# <AxesSubplot: xlabel='Mapped bases', ylabel='Reads'>
